# %%
# %matplotlib inline
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import pylab as pl
import numpy as np
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt
import statsmodels.api as sm
def stats(y_true,y_pred):
    
    from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
    print "-----------EVALUATION STATISTICS------------"
    print 'Mean absolute Error : ', mean_absolute_error(test_Y.values, y_pred)
    print 'Mean squared Error : ', mean_squared_error(y_true, y_pred)
    print 'R2 score : ', r2_score(y_true, y_pred)

# %%
df_data2 = pd.read_csv('../data/../data/finaldata_profession_corrected_dob.csv', error_bad_lines=False, delimiter='~')
df_data2 = df_data2[df_data2.DOB1 > 1870]
df_data2 = df_data2[df_data2.Age > 35]
df_data2 = df_data2[df_data2.Age < 120]
df_data2.to_csv('dataforsravnathi.csv')
df_data = pd.read_csv('../data/freebasedata_profession.csv', error_bad_lines=False, delimiter='~')
df_data2['LifeExpnAge'] = df_data2['LifeExpectancy']+df_data2['Age']

# %%
df_dataa = pd.read_csv('dataforsravnathi.csv', error_bad_lines=False)
df_male=pd.read_csv('../data/male_lifeexp.csv', error_bad_lines=False)
df_female=pd.read_csv('../data/female_lifeexp.csv', error_bad_lines=False)
malemat=df_male.as_matrix(columns=None)
femalemat=df_female.as_matrix(columns=None)
yearlist=[1925,1950,1975]
yr1=1925
yr2=1950
yr3=1975
#1925,1950,1975

# %%
'''#calculating age, Life expectancy, Probability 
df_dataa['LifeExpectancycyr'] = Series(None, index=df_dataa.index)
df_dataa['currentYr'] = Series(None, index=df_dataa.index)
df_temp = DataFrame(columns=df_dataa.columns)
loc=0
for index, row in df_dataa.iterrows():
    dob=row['DOB1']
    dod=row['DOD1']
    if yr1 < dod and yr1 > dob:
        age=yr1-dob
        if row['gender']==0:
            row['LifeExpectancycyr']=malemat[age][1]
        else :
            row['LifeExpectancycyr']=femalemat[age][1]
        row['currentYr'] =yr1
        df_temp.loc[index]=row
        index=index+1
    if yr2 < dod and yr2 > dob:
        age=yr2-dob
        if row['gender']==0:
            row['LifeExpectancycyr']=malemat[age][1]
        else :
            row['LifeExpectancycyr']=femalemat[age][1]
        row['currentYr'] =yr2
        df_temp.loc[index]=row
        index=index+1
    if yr3 < dod and yr3 > dob:
        age=yr3-dob
        if row['gender']==0:
            row['LifeExpectancycyr']=malemat[age][1]
        else :
            row['LifeExpectancycyr']=femalemat[age][1]
        row['currentYr'] =yr3
        df_temp.loc[index]=row
        index=index+1
        
'''
# Out:
# "#calculating age, Life expectancy, Probability \ndf_dataa['LifeExpectancycyr'] = Series(None, index=df_dataa.index)\ndf_dataa['currentYr'] = Series(None, index=df_dataa.index)\ndf_temp = DataFrame(columns=df_dataa.columns)\nloc=0\nfor index, row in df_dataa.iterrows():\n    dob=row['DOB1']\n    dod=row['DOD1']\n    if yr1 < dod and yr1 > dob:\n        age=yr1-dob\n        if row['gender']==0:\n            row['LifeExpectancycyr']=malemat[age][1]\n        else :\n            row['LifeExpectancycyr']=femalemat[age][1]\n        row['currentYr'] =yr1\n        df_temp.loc[index]=row\n        index=index+1\n    if yr2 < dod and yr2 > dob:\n        age=yr2-dob\n        if row['gender']==0:\n            row['LifeExpectancycyr']=malemat[age][1]\n        else :\n            row['LifeExpectancycyr']=femalemat[age][1]\n        row['currentYr'] =yr2\n        df_temp.loc[index]=row\n        index=index+1\n    if yr3 < dod and yr3 > dob:\n        age=yr3-dob\n        if row['gender']==0:\n            row['LifeExpectancycyr']=malemat[age][1]\n        else :\n            row['LifeExpectancycyr']=femalemat[age][1]\n        row['currentYr'] =yr3\n        df_temp.loc[index]=row\n        index=index+1\n        \n"

# %%
print df_data2.shape
print df_data2.columns
#remving Nans and NOnes
df_data2 = df_data2.replace('unknown', np.nan)
df_data2 = df_data2.replace('none', np.nan)
df_data2=df_data2.fillna(df_data2.median())
print df_data2.shape
print df_data2.columns
# Out:
# (93312, 78)
# Index([u'Unnamed: 0', u'Unnamed: 0.1', u'Unnamed: 0.1', u'Name', u'/people/cause_of_death/parent_cause_of_death', u'/people/cause_of_death/includes_causes_of_death', u'/people/cause_of_death/people', u'DOD', u'/people/deceased_person/place_of_death', u'/people/deceased_person/cause_of_death', u'/people/deceased_person/date_of_cremation', u'/people/deceased_person/place_of_cremation', u'/people/deceased_person/date_of_burial', u'/people/deceased_person/place_of_burial', u'/people/ethnicity/included_in_group', u'/people/ethnicity/includes_groups', u'/people/ethnicity/geographic_distribution', u'/people/ethnicity/languages_spoken', u'/people/ethnicity/population', u'/people/ethnicity/people', u'/people/family_name/people_with_this_family_name', u'/people/group/member', u'/people/measured_person/measurements', u'/people/measured_person/sizes', u'DOB', u'/people/person/place_of_birth', u'/people/person/nationality', u'/people/person/gender', u'/people/person/profession', u'/people/person/religion', u'/people/person/ethnicity', u'/people/person/parents', u'/people/person/children', u'/people/person/sibling_s', u'/people/person/spouse_s', u'/people/person/employment_history', u'/people/person/education', u'/people/person/metaweb_user_s', u'/people/person/signature', u'/people/person/height_meters', u'/people/person/weight_kg', u'/people/person/quotations', u'/people/person/places_lived', u'/people/person/quotationsbook_id', u'/people/person/age', u'/people/person/tvrage_id', u'/people/person/notable_professions', u'/people/person/languages', u'/people/person/group', u'/people/professional_field/professions_in_this_field', u'/people/profession/people_with_this_profession', u'/people/profession/specialization_of', u'/people/profession/specializations', u'/people/profession/part_of_professional_field', u'Unnamed: 51', u'LifeExpectancy', u'Age', u'Probability', u'profession', u'gender', u'nationality', u'nationality_no', u'Politician', u'Pope-elect', u'Diplomat', u'Evangelist', u'Business magnate', u'Astronaut', u'Musician', u'Physicist', u'Actress', u'Actor', u'Guitarist', u'Singer', u'Pianist', u'DOB1', u'DOD1', u'LifeExpnAge'], dtype='object')
# (93312, 78)
# Index([u'Unnamed: 0', u'Unnamed: 0.1', u'Unnamed: 0.1', u'Name', u'/people/cause_of_death/parent_cause_of_death', u'/people/cause_of_death/includes_causes_of_death', u'/people/cause_of_death/people', u'DOD', u'/people/deceased_person/place_of_death', u'/people/deceased_person/cause_of_death', u'/people/deceased_person/date_of_cremation', u'/people/deceased_person/place_of_cremation', u'/people/deceased_person/date_of_burial', u'/people/deceased_person/place_of_burial', u'/people/ethnicity/included_in_group', u'/people/ethnicity/includes_groups', u'/people/ethnicity/geographic_distribution', u'/people/ethnicity/languages_spoken', u'/people/ethnicity/population', u'/people/ethnicity/people', u'/people/family_name/people_with_this_family_name', u'/people/group/member', u'/people/measured_person/measurements', u'/people/measured_person/sizes', u'DOB', u'/people/person/place_of_birth', u'/people/person/nationality', u'/people/person/gender', u'/people/person/profession', u'/people/person/religion', u'/people/person/ethnicity', u'/people/person/parents', u'/people/person/children', u'/people/person/sibling_s', u'/people/person/spouse_s', u'/people/person/employment_history', u'/people/person/education', u'/people/person/metaweb_user_s', u'/people/person/signature', u'/people/person/height_meters', u'/people/person/weight_kg', u'/people/person/quotations', u'/people/person/places_lived', u'/people/person/quotationsbook_id', u'/people/person/age', u'/people/person/tvrage_id', u'/people/person/notable_professions', u'/people/person/languages', u'/people/person/group', u'/people/professional_field/professions_in_this_field', u'/people/profession/people_with_this_profession', u'/people/profession/specialization_of', u'/people/profession/specializations', u'/people/profession/part_of_professional_field', u'Unnamed: 51', u'LifeExpectancy', u'Age', u'Probability', u'profession', u'gender', u'nationality', u'nationality_no', u'Politician', u'Pope-elect', u'Diplomat', u'Evangelist', u'Business magnate', u'Astronaut', u'Musician', u'Physicist', u'Actress', u'Actor', u'Guitarist', u'Singer', u'Pianist', u'DOB1', u'DOD1', u'LifeExpnAge'], dtype='object')

# %%
#removing NaN values
df_data2 = df_data2.replace('unknown', np.nan)
df_data2 = df_data2.replace('none', np.nan)
df_data2 = df_data2.fillna(df_data2.median())

# %%
#extracting fields for regression model
df_data_X=pd.concat([df_data2['DOB1'], df_data2['LifeExpnAge'],df_data2['gender'],df_data2['nationality_no'],df_data2['Politician'],df_data2['Diplomat'],df_data2['Evangelist'],df_data2['Business magnate'],df_data2['Astronaut'],df_data2['Musician'],df_data2['Physicist'],df_data2['Actor'],df_data2['Guitarist'],df_data2['Singer'],df_data2['Pianist']],axis=1)
df_data_Y=pd.concat([df_data2['DOD1']],axis=1)

# %%
msk = np.random.rand(len(df_data2)) < 0.8
train_X = df_data_X[msk]
test_X = df_data_X[~msk]
train_Y = df_data_Y[msk]
test_Y = df_data_Y[~msk]
train_X = train_X.replace('unknown', np.nan)
train_X = train_X.replace('none', np.nan)
train_X=train_X.fillna(train_X.median())
test_X = test_X.replace('unknown', np.nan)
test_X = test_X.replace('none', np.nan)
test_X= test_X.fillna(test_X.median())
test_Y = test_Y.replace('unknown', np.nan)
test_Y = test_Y.replace('none', np.nan)
test_Y= test_Y.fillna(test_Y.median())
train_Y = train_Y.replace('unknown', np.nan)
train_Y = train_Y.replace('none', np.nan)
train_Y=train_Y.fillna(train_Y.median())
print train_X.shape
print train_Y.shape
test_X.columns
# Out:
# (74559, 15)
# (74559, 1)
# Index([u'DOB1', u'LifeExpnAge', u'gender', u'nationality_no', u'Politician', u'Diplomat', u'Evangelist', u'Business magnate', u'Astronaut', u'Musician', u'Physicist', u'Actor', u'Guitarist', u'Singer', u'Pianist'], dtype='object')

# %%
#print X_train.columns
#Index([u'LifeExpectancy', u'gender', u'nationality_no', u'profession1'], dtype='object')
#Pope-elect +
#Business magnate + 
'''
fml = "Age ~ 0 + gender + nationality_no + Politician + Diplomat + Evangelist + Astronaut + Musician + Physicist + Actress + Actor + Guitarist + Singer + Pianist+ LifeExpectancy"
mod = sm.OLS.from_formula(fml, train)
rslt = mod.fit() # Linear reg
#rslt = sm.OLS(train_X, train_Y).fit()
#rslt.predict
print rslt.summary()
y_pred = rslt.predict(test_X)
def stats(y_true,y_pred):
    
    from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
    print "-----------EVALUATION STATISTICS------------"
    print 'Mean absolute Error : ', mean_absolute_error(test_Y.values, y_pred)
    print 'Mean squared Error : ', mean_squared_error(y_true, y_pred)
    print 'R2 score : ', r2_score(y_true, y_pred)
stats(test_Y.values, y_pred)
'''
# Out:
# '\nfml = "Age ~ 0 + gender + nationality_no + Politician + Diplomat + Evangelist + Astronaut + Musician + Physicist + Actress + Actor + Guitarist + Singer + Pianist+ LifeExpectancy"\nmod = sm.OLS.from_formula(fml, train)\nrslt = mod.fit() # Linear reg\n#rslt = sm.OLS(train_X, train_Y).fit()\n#rslt.predict\nprint rslt.summary()\ny_pred = rslt.predict(test_X)\ndef stats(y_true,y_pred):\n    \n    from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score\n    print "-----------EVALUATION STATISTICS------------"\n    print \'Mean absolute Error : \', mean_absolute_error(test_Y.values, y_pred)\n    print \'Mean squared Error : \', mean_squared_error(y_true, y_pred)\n    print \'R2 score : \', r2_score(y_true, y_pred)\nstats(test_Y.values, y_pred)\n'

# %%
'''#plots
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(rslt, fig=fig)'''
# Out:
# '#plots\nfig = plt.figure(figsize=(12,8))\nfig = sm.graphics.plot_partregress_grid(rslt, fig=fig)'

# %%
'''#fig = plt.figure(figsize=(12,8))
#fig = sm.graphics.influence_plot(rslt, fig=fig)'''
# Out:
# '#fig = plt.figure(figsize=(12,8))\n#fig = sm.graphics.influence_plot(rslt, fig=fig)'

# %%
train_X = sm.add_constant(train_X)
res = sm.OLS(train_Y, train_X).fit()# non?Linear reg
print res.summary()
test_X = sm.add_constant(test_X)
y_pred = res.predict(test_X)
stats(test_Y.values, y_pred)
fig = plt.figure(figsize=(20, 16))
ax = fig.add_subplot(1,1,1)
ax.scatter(test_Y.values, y_pred)
#plt.colorbar()
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
ax.set_xlabel('Actual year of Death', fontsize=20)
ax.set_ylabel('Predicted year of Death', fontsize=20)
ax.set_title('Prection vs Actual YOD - Evaluation', fontsize=20)

ax.grid(True)
fig.tight_layout()

plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   DOD1   R-squared:                       0.841
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                 2.627e+04
# Date:                Thu, 13 Nov 2014   Prob (F-statistic):               0.00
# Time:                        06:06:05   Log-Likelihood:            -2.7143e+05
# No. Observations:               74559   AIC:                         5.429e+05
# Df Residuals:                   74543   BIC:                         5.430e+05
# Df Model:                          15
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const              159.1085      3.110     51.164      0.000       153.013   165.204
# DOB1                 0.8962      0.002    558.859      0.000         0.893     0.899
# LifeExpnAge          1.3185      0.004    312.955      0.000         1.310     1.327
# gender              -2.8246      0.113    -25.095      0.000        -3.045    -2.604
# nationality_no      -0.0023      0.000     -7.403      0.000        -0.003    -0.002
# Politician          -1.3539      0.156     -8.699      0.000        -1.659    -1.049
# Diplomat            -0.0822      0.593     -0.139      0.890        -1.245     1.080
# Evangelist          -4.5043      3.074     -1.465      0.143       -10.530     1.522
# Business magnate    -3.1494      1.923     -1.637      0.102        -6.919     0.621
# Astronaut           -6.5705      1.319     -4.981      0.000        -9.156    -3.985
# Musician            -2.7034      0.350     -7.729      0.000        -3.389    -2.018
# Physicist            0.2418      0.447      0.541      0.588        -0.634     1.117
# Actor               -1.3523      0.104    -12.999      0.000        -1.556    -1.148
# Guitarist           -3.0794      0.885     -3.478      0.001        -4.815    -1.344
# Singer              -1.4782      0.260     -5.690      0.000        -1.987    -0.969
# Pianist             -0.4952      0.528     -0.939      0.348        -1.529     0.539
# ==============================================================================
# Omnibus:                     3569.260   Durbin-Watson:                   1.695
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5628.287
# Skew:                          -0.420   Prob(JB):                         0.00
# Kurtosis:                       4.051   Cond. No.                     1.76e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.76e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# -----------EVALUATION STATISTICS------------
# Mean absolute Error :  6.81152063762
# Mean squared Error :  83.5203162601
# R2 score :  0.844612981299

# %%
'''from statsmodels.sandbox.regression.predstd import wls_prediction_std
plt.figure();
plt.plot(train_X.values, train_Y.values, 'o', test_X.values, y_pred, 'b-');
prstd, iv_l, iv_u = wls_prediction_std(res);
plt.plot(train_X, res.fittedvalues, 'r--.');
plt.plot(train_X, iv_u, 'r--');
plt.plot(train_X, iv_l, 'r--');
plt.title('blue: true,   red: OLS');'''
# Out:
# "from statsmodels.sandbox.regression.predstd import wls_prediction_std\nplt.figure();\nplt.plot(train_X.values, train_Y.values, 'o', test_X.values, y_pred, 'b-');\nprstd, iv_l, iv_u = wls_prediction_std(res);\nplt.plot(train_X, res.fittedvalues, 'r--.');\nplt.plot(train_X, iv_u, 'r--');\nplt.plot(train_X, iv_l, 'r--');\nplt.title('blue: true,   red: OLS');"

# %%
df_real_32_data = pd.read_csv('../data/celebrities_32_final.csv', error_bad_lines=False)
df_real_32_data['LifeExpnAge'] = df_real_32_data['LifeExpectancy']+df_real_32_data['Age']
df_real_32_data.columns
df_real_32_data_X = df_real_32_data[['DOB','LifeExpnAge','gender','nationality_no', 'Politician', 'Diplomat', 'Evangelist', 'Business magnate', 'Astronaut', 'Musician','Physicist','Actor','Guitarist','Singer','Pianist']]
df_real_32_data_X = sm.add_constant(df_real_32_data_X)
y_pred = res.predict(df_real_32_data_X)
#df_real_32_data.columns
df_real_32_data['pred_age'] = abs(y_pred)
df_real_32_data[['Name','Age','pred_age','LifeExpnAge','Occupation']].sort(columns='pred_age', ascending=True)
# Out:
#                           Name  Age     pred_age  LifeExpnAge  \
# 16                  John Glenn   93  2000.999191        96.20
# 13           Rev. Billy Graham   96  2003.567478        98.62
# 26                 Chuck Berry   88  2004.277608        92.64
# 0           Queen Elizabeth II   88  2004.382429        93.56
# 22               Zsa Zsa Gabor   97  2004.511033        99.94
# 23                   B.B. King   89  2004.627541        93.30
# 21         Olivia de Havilland   98  2004.727710       100.76
# 14              Rupert Murdoch   83  2004.741922        89.65
# 20               Dick van Dyke   88  2005.108454        92.64
# 17              Charles Manson   79  2005.217717        87.63
# 5                Robert Mugabe   90  2005.473654        93.99
# 19                   Doris Day   90  2005.587878        94.80
# 9               Helmut Schmidt   95  2005.621249        97.79
# 3                 Fidel Castro   88  2005.796761        92.64
# 6                 Shimon Peres   91  2005.853652        94.70
# 12                Lee Kwan Yew   91  2005.948878        94.70
# 2                 Jimmy Carter   90  2005.990598        93.99
# 1   George Herbert Walker Bush   90  2005.990598        93.99
# 8                Hosni Mubarak   86  2006.023138        91.38
# 25                Kirk Douglas   97  2006.047708        99.47
# 30                  Abe Vigoda   93  2006.217366        96.20
# 24              Clint Eastwood   84  2006.385631        90.21
# 31                 Fats Domino   86  2006.992907        91.38
# 10             Henry Kissinger   91  2007.299906        94.70
# 27             Jerry Lee Lewis   79  2007.339203        87.63
# 4                Pope Benedict   87  2007.407108        92.00
# 29              Keith Richards   70  2008.580803        84.07
# 7                 Ali Khamenei   75  2008.747362        85.89
# 28                 Mick Jagger   71  2009.015900        84.40
# 15                 Dick Cheney   73  2009.531366        85.12
# 18             Stephen Hawking   72  2011.526374        84.75
# 11             Bashar al-Assad   49  2022.924433        79.31
#
#           Occupation
# 16         Astronaut
# 13        Evangelist
# 26         Guitarist
# 0         Politician
# 22           Actress
# 23          Musician
# 21           Actress
# 14  Business magnate
# 20             Actor
# 17          Musician
# 5         Politician
# 19           Actress
# 9         Politician
# 3         Politician
# 6         Politician
# 12        Politician
# 2         Politician
# 1         Politician
# 8         Politician
# 25             Actor
# 30             Actor
# 24             Actor
# 31           Pianist
# 10          Diplomat
# 27            Singer
# 4         Pope-elect
# 29          Musician
# 7         Politician
# 28          Musician
# 15        Politician
# 18         Physicist
# 11        Politician

# %%
'''df_dummy = pd.read_csv('../data/finaldata_profession_corrected_dob.csv', delimiter='~')
df_dummy = df_dummy[df_dummy.DOB1 > 1900]
print df_dummy.shape'''

# %%
'''df_data_test = pd.read_csv('../data/celebrities_32_final.csv', error_bad_lines=False)
#print df_data_test

df_data_test['profession1'] = Series(1, index=df_data_test.index)
df_data_test['gender']=Series(None, index=df_data_test.index)
for index, row in df_data_test.iterrows():
    if row['Gender']=='Male':
        df_data2.loc[index,'gender1']=0
    if row['Gender']=='Female':
        df_data2.loc[index,'gender1']=1
#df_data_test
#df_test=pd.concat([df_data_test['LifeExpectancy'],df_data_test['gender'],df_data_test['nationality_no'],df_data_test['profession1']],axis=1)
print df_data_test
#print 24.2059*df_data_test['LifeExpectancy']+0.0599*df_data_test['nationality_no']+35.3053*df_data_test['profession1']+1.7473 *df_data_test['LifeExpectancy']
data_results=rslt.predict(df_data_test)
print data_results

#df_data_Y=pd.concat([df_data2['Age']],axis=1)
#df_data_test
'''

# %%
'''# load the boston housing dataset - median house values in the Boston area
df = pd.read_csv('http://vincentarelbundock.github.io/Rdatasets/csv/MASS/Boston.csv')

# plot lstat (% lower status of the population) against median value
plt.figure(figsize=(6 * 1.618, 6))
plt.scatter(df.lstat, df.medv, s=10, alpha=0.3)
plt.xlabel('lstat')
plt.ylabel('medv')

# points linearlyd space on lstats
x = pd.DataFrame({'lstat': np.linspace(df.lstat.min(), df.lstat.max(), 100)})

# 1-st order polynomial
poly_1 = smf.ols(formula='medv ~ 1 + lstat', data=df).fit()
plt.plot(x.lstat, poly_1.predict(x), 'b-', label='Poly n=1 $R^2$=%.2f' % poly_1.rsquared, 
         alpha=0.9)

# 2-nd order polynomial
poly_2 = smf.ols(formula='medv ~ 1 + lstat + I(lstat ** 2.0)', data=df).fit()
plt.plot(x.lstat, poly_2.predict(x), 'g-', label='Poly n=2 $R^2$=%.2f' % poly_2.rsquared, 
         alpha=0.9)

# 3-rd order polynomial
poly_3 = smf.ols(formula='medv ~ 1 + lstat + I(lstat ** 2.0) + I(lstat ** 3.0)', data=df).fit()
plt.plot(x.lstat, poly_3.predict(x), 'r-', alpha=0.9,
         label='Poly n=3 $R^2$=%.2f' % poly_3.rsquared)

plt.legend()'''
